# %% [markdown]
# # import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os
encoding = 'latin1'

# %% [markdown]
# # Updating the columns for user data

# %%
userDataPath = os.path.expanduser('MovielensData/users.dat')
unames = ['user_id', 'gender', 'age', 'occupation', 'zip']
users = pd.read_csv(userDataPath, sep='::', header=None, names=unames, encoding=encoding)
# Out:
# /home/seshendra/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-1035d96022cc> in <module>
#       1 userDataPath = os.path.expanduser('MovielensData/users.dat')
#       2 unames = ['user_id', 'gender', 'age', 'occupation', 'zip']
# ----> 3 users = pd.read_csv(userDataPath, sep='::', header=None, names=unames, encoding=encoding)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1130                                  ' "c", "python", or' ' "python-fwf")'.format(
#    1131                                      engine=engine))
# -> 1132             self._engine = klass(self.f, **self.options)
#    1133
#    1134     def _failover_to_python(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, **kwds)
#    2223         f, handles = _get_handle(f, mode, encoding=self.encoding,
#    2224                                  compression=self.compression,
# -> 2225                                  memory_map=self.memory_map)
#    2226         self.handles.extend(handles)
#    2227
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     422         elif encoding:
#     423             # Python 3 and encoding
# --> 424             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     425         elif is_text:
#     426             # Python 3 and no explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'MovielensData/users.dat'

# %%
users.columns
# Out:
# Index(['user_id', 'gender', 'age', 'occupation', 'zip'], dtype='object')

# %%
users.describe()
# Out:
#            user_id          age   occupation
# count  6040.000000  6040.000000  6040.000000
# mean   3020.500000    30.639238     8.146854
# std    1743.742145    12.895962     6.329511
# min       1.000000     1.000000     0.000000
# 25%    1510.750000    25.000000     3.000000
# 50%    3020.500000    25.000000     7.000000
# 75%    4530.250000    35.000000    14.000000
# max    6040.000000    56.000000    20.000000

# %% [markdown]
# # Ratings Movie data set

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6040 entries, 0 to 6039
# Data columns (total 5 columns):
# user_id       6040 non-null int64
# gender        6040 non-null object
# age           6040 non-null int64
# occupation    6040 non-null int64
# zip           6040 non-null object
# dtypes: int64(3), object(2)
# memory usage: 236.0+ KB

# %%
ratingDataPath = os.path.expanduser('MovielensData/ratings.dat')
rnames = ['user_id','movie_id', 'Rating', 'timestamp']
ratings = pd.read_csv(ratingDataPath, sep='::', header=None, names=rnames, encoding=encoding)
# Out:
# /home/seshendra/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
ratings.columns
# Out:
# Index(['user_id', 'movie_id', 'Rating', 'timestamp'], dtype='object')

# %%
ratings.describe()
# Out:
#             user_id      movie_id        Rating     timestamp
# count  1.000209e+06  1.000209e+06  1.000209e+06  1.000209e+06
# mean   3.024512e+03  1.865540e+03  3.581564e+00  9.722437e+08
# std    1.728413e+03  1.096041e+03  1.117102e+00  1.215256e+07
# min    1.000000e+00  1.000000e+00  1.000000e+00  9.567039e+08
# 25%    1.506000e+03  1.030000e+03  3.000000e+00  9.653026e+08
# 50%    3.070000e+03  1.835000e+03  4.000000e+00  9.730180e+08
# 75%    4.476000e+03  2.770000e+03  4.000000e+00  9.752209e+08
# max    6.040000e+03  3.952000e+03  5.000000e+00  1.046455e+09

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000209 entries, 0 to 1000208
# Data columns (total 4 columns):
# user_id      1000209 non-null int64
# movie_id     1000209 non-null int64
# Rating       1000209 non-null int64
# timestamp    1000209 non-null int64
# dtypes: int64(4)
# memory usage: 30.5 MB

# %% [markdown]
# # Movie Data Set

# %%
movieDataPath = os.path.expanduser('MovielensData/movies.dat')
mnames = ['movie_id', 'title', 'genres']
movies = pd.read_csv(movieDataPath, sep='::', header=None, names=mnames, encoding=encoding)
# Out:
# /home/seshendra/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3883 entries, 0 to 3882
# Data columns (total 3 columns):
# movie_id    3883 non-null int64
# title       3883 non-null object
# genres      3883 non-null object
# dtypes: int64(1), object(2)
# memory usage: 91.1+ KB

# %%
movies.describe()
# Out:
#           movie_id
# count  3883.000000
# mean   1986.049446
# std    1146.778349
# min       1.000000
# 25%     982.500000
# 50%    2010.000000
# 75%    2980.500000
# max    3952.000000

# %%
movies.head(5)
# Out:
#    movie_id                               title                        genres
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy

# %%
ratings.head()
# Out:
#    user_id  movie_id  Rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
print(users[:5])
print(movies[:5])
print(ratings[:5])
# Out:
#    user_id gender  age  occupation    zip
# 0        1      F    1          10  48067
# 1        2      M   56          16  70072
# 2        3      M   25          15  55117
# 3        4      M   45           7  02460
# 4        5      M   25          20  55455
#    movie_id                               title                        genres
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy
#    user_id  movie_id  Rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %% [markdown]
# # Combining the data

# %%
URData =  pd.merge(users, ratings, on ='user_id')

# %%
print(URData[:5])
# Out:
#    user_id gender  age  occupation    zip  movie_id  Rating  timestamp
# 0        1      F    1          10  48067      1193       5  978300760
# 1        1      F    1          10  48067       661       3  978302109
# 2        1      F    1          10  48067       914       3  978301968
# 3        1      F    1          10  48067      3408       4  978300275
# 4        1      F    1          10  48067      2355       5  978824291

# %%
print(movies[:5])
# Out:
#    movie_id                               title                        genres
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy

# %%
masterData = pd.merge(URData, movies, on='movie_id')

# %%
masterData.head()
# Out:
#    user_id gender  age  occupation    zip  movie_id  Rating  timestamp  \
# 0        1      F    1          10  48067      1193       5  978300760
# 1        2      M   56          16  70072      1193       5  978298413
# 2       12      M   25          12  32793      1193       4  978220179
# 3       15      M   25           7  22903      1193       4  978199279
# 4       17      M   50           1  95350      1193       5  978158471
#
#                                     title genres
# 0  One Flew Over the Cuckoo's Nest (1975)  Drama
# 1  One Flew Over the Cuckoo's Nest (1975)  Drama
# 2  One Flew Over the Cuckoo's Nest (1975)  Drama
# 3  One Flew Over the Cuckoo's Nest (1975)  Drama
# 4  One Flew Over the Cuckoo's Nest (1975)  Drama

# %% [markdown]
# # Combining the data in one line

# %%
combineData = pd.merge(pd.merge(ratings, users, on='user_id'), movies, on='movie_id')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-058d4f36c807> in <module>
# ----> 1 combineData = pd.merge(pd.merge(ratings, users, on='user_id'), movies, on='movie_id')
#
# NameError: name 'pd' is not defined

# %%
combineData.head()
# Out:
#    user_id  movie_id  Rating  timestamp gender  age  occupation    zip  \
# 0        1      1193       5  978300760      F    1          10  48067
# 1        2      1193       5  978298413      M   56          16  70072
# 2       12      1193       4  978220179      M   25          12  32793
# 3       15      1193       4  978199279      M   25           7  22903
# 4       17      1193       5  978158471      M   50           1  95350
#
#                                     title genres
# 0  One Flew Over the Cuckoo's Nest (1975)  Drama
# 1  One Flew Over the Cuckoo's Nest (1975)  Drama
# 2  One Flew Over the Cuckoo's Nest (1975)  Drama
# 3  One Flew Over the Cuckoo's Nest (1975)  Drama
# 4  One Flew Over the Cuckoo's Nest (1975)  Drama

# %% [markdown]
# # Explore the datasets using visual representations (graphs or tables), also include your comments on the following:
# # 1. User Age Distribution

# %%
combineData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000209 entries, 0 to 1000208
# Data columns (total 10 columns):
# user_id       1000209 non-null int64
# movie_id      1000209 non-null int64
# Rating        1000209 non-null int64
# timestamp     1000209 non-null int64
# gender        1000209 non-null object
# age           1000209 non-null int64
# occupation    1000209 non-null int64
# zip           1000209 non-null object
# title         1000209 non-null object
# genres        1000209 non-null object
# dtypes: int64(6), object(4)
# memory usage: 83.9+ MB

# %%
combineData.columns
# Out:
# Index(['user_id', 'movie_id', 'Rating', 'timestamp', 'gender', 'age',
#        'occupation', 'zip', 'title', 'genres'],
#       dtype='object')

# %%
# Find the ratings for all the movies reviewed by for a particular user of user id = 2696
combineData[combineData['user_id'] == 2696]['Rating']
# Out:
# 24345     2
# 29848     3
# 244232    4
# 250014    5
# 273633    1
# 277808    4
# 371178    4
# 377250    3
# 598042    4
# 603189    4
# 609204    4
# 611956    2
# 612552    4
# 613486    4
# 616546    4
# 618708    4
# 621101    1
# 689379    4
# 697451    2
# 777089    3
# Name: Rating, dtype: int64

# %% [markdown]
# # Data Visualization --> Top rated 25 movies

# %%
most_rated = combineData.groupby('age').size().sort_values(ascending=False)[:25]
most_rated.head(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0cbb72beed68> in <module>
# ----> 1 most_rated = combineData.groupby('age').size().sort_values(ascending=False)[:25]
#       2 most_rated.head(25)
#
# NameError: name 'combineData' is not defined

# %% [markdown]
# # Data Visualization --> User rating of the movie “Toy Story”

# %%
# get the ratings count for each title
ratings_count = combineData[['title', 'Rating']]
ratings_count
# Out:
#                                                      title  Rating
# 0                   One Flew Over the Cuckoo's Nest (1975)   False
# 1                   One Flew Over the Cuckoo's Nest (1975)   False
# 2                   One Flew Over the Cuckoo's Nest (1975)   False
# 3                   One Flew Over the Cuckoo's Nest (1975)   False
# 4                   One Flew Over the Cuckoo's Nest (1975)   False
# 5                   One Flew Over the Cuckoo's Nest (1975)   False
# 6                   One Flew Over the Cuckoo's Nest (1975)   False
# 7                   One Flew Over the Cuckoo's Nest (1975)   False
# 8                   One Flew Over the Cuckoo's Nest (1975)   False
# 9                   One Flew Over the Cuckoo's Nest (1975)   False
# 10                  One Flew Over the Cuckoo's Nest (1975)   False
# 11                  One Flew Over the Cuckoo's Nest (1975)   False
# 12                  One Flew Over the Cuckoo's Nest (1975)   False
# 13                  One Flew Over the Cuckoo's Nest (1975)   False
# 14                  One Flew Over the Cuckoo's Nest (1975)   False
# 15                  One Flew Over the Cuckoo's Nest (1975)   False
# 16                  One Flew Over the Cuckoo's Nest (1975)   False
# 17                  One Flew Over the Cuckoo's Nest (1975)   False
# 18                  One Flew Over the Cuckoo's Nest (1975)   False
# 19                  One Flew Over the Cuckoo's Nest (1975)   False
# 20                  One Flew Over the Cuckoo's Nest (1975)   False
# 21                  One Flew Over the Cuckoo's Nest (1975)   False
# 22                  One Flew Over the Cuckoo's Nest (1975)   False
# 23                  One Flew Over the Cuckoo's Nest (1975)   False
# 24                  One Flew Over the Cuckoo's Nest (1975)   False
# 25                  One Flew Over the Cuckoo's Nest (1975)   False
# 26                  One Flew Over the Cuckoo's Nest (1975)   False
# 27                  One Flew Over the Cuckoo's Nest (1975)   False
# 28                  One Flew Over the Cuckoo's Nest (1975)   False
# 29                  One Flew Over the Cuckoo's Nest (1975)   False
# ...                                                    ...     ...
# 1000179                                   Home Page (1999)   False
# 1000180                            Juno and Paycock (1930)   False
# 1000181                                Detroit 9000 (1973)   False
# 1000182                               Condition Red (1995)   False
# 1000183                               Stranger, The (1994)   False
# 1000184                               Stranger, The (1994)   False
# 1000185                                  Truce, The (1996)   False
# 1000186                                  Truce, The (1996)   False
# 1000187  Brother Minister: The Assassination of Malcolm...   False
# 1000188  Brother Minister: The Assassination of Malcolm...   False
# 1000189  Brother Minister: The Assassination of Malcolm...   False
# 1000190  Brother Minister: The Assassination of Malcolm...   False
# 1000191                          Six Ways to Sunday (1997)   False
# 1000192                          Six Ways to Sunday (1997)   False
# 1000193                            Tough and Deadly (1995)   False
# 1000194                            Tough and Deadly (1995)   False
# 1000195                                       Lured (1947)   False
# 1000196                               Outside Ozona (1998)   False
